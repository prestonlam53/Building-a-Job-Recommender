# %%
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from nltk.tokenize import TreebankWordTokenizer
from nltk.stem import PorterStemmer
from sklearn.decomposition import TruncatedSVD, NMF
from sklearn.metrics.pairwise import cosine_similarity
import re
import numpy as np
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_score, train_test_split, GridSearchCV
from sklearn.metrics import accuracy_score
from sklearn.decomposition import PCA

# %%
resumes = pd.read_csv('resumes.csv')

# %%
resumes
# Out:
#                                              Resumes            Person
# 0  eCommerce Analyst / Category Specialist\nCompa...     Ryan Clohessy
# 1  Experience\nElectronic Arts (EA)\nGlobal Marco...  Russell Escalada
# 2  Experience\nWalmart eCommerce\nCompany NameWal...            Xiu Li
# 3  Experience\nAvascent\nCompany NameAvascent\nTo...     Shawdon Zadeh
# 4  Courtney Schaf\n 1st degree connection1st\nCou...    Courtney Schaf
# 5  Preston Lam\nPreston has a account\nData Scien...       Preston Lam

# %%
import pandas as pd
df = pd.read_csv('jobs.csv')

# %%
# %%time
def tokenize_stem(series):

    tokenizer =TreebankWordTokenizer()
    stemmer = PorterStemmer()
    series = series.apply(lambda x: tokenizer.tokenize(x))
    series = series.apply(lambda x: [stemmer.stem(w) for w in x])
    series = series.apply(lambda x: ' '.join(x))
    return series

def display_topics(model, feature_names, no_top_words, topic_names=None):
    topic_list = []
    for i, topic in enumerate(model.components_):
        if not topic_names or not topic_names[i]:
            print("\nTopic ", i)
        else:
            print("\nTopic: '",topic_names[i],"'")
        
        print(", ".join([feature_names[k]
                       for k in topic.argsort()[:-no_top_words - 1:-1]]))
        topic_list.append(", ".join([feature_names[k]
                       for k in topic.argsort()[:-no_top_words - 1:-1]]))
    return model.components_, topic_list


def return_topics(series, num_topics, no_top_words, model, vectorizer):
    #turn job into series
    series = tokenize_stem(series)
    #transform series into corpus
    ex_label = [e[:30]+"..." for e in series]
    #set vectorizer ngrams = (2,2)
    vec = vectorizer(stop_words = 'english')

    doc_word = vec.fit_transform(series)

    #build model
    def_model = model(num_topics)
    doc_topic = def_model.fit_transform(doc_word)
    print('model components: ', def_model.components_[0].shape)
    print('doc_topic', doc_topic[0])
    model_components, topic_list = display_topics(def_model, vec.get_feature_names(), no_top_words)
    return def_model.components_, doc_topic, def_model, vec, topic_list#, topics

def process_data():
    #read in jobs file and get descriptions
    df = pd.read_csv('jobs.csv')
    #df = df[df.keyword!='marketing']
    jobs_df = pd.DataFrame(zip(df['Job Description'], df['keyword']), columns = ['Description', 'Job'])

    array, doc, topic_model, vec, topic_list  = return_topics(jobs_df['Description'],20, 10, TruncatedSVD, TfidfVectorizer)
    doc.shape

    topic_df = pd.DataFrame(doc)
    topic_df.columns = ['Topic ' + str(i+1) for i in range(len(topic_df.columns)) ]

    topic_df['job'] = jobs_df.Job
    #Topic_DF.to_csv('topic_df.csv')
    return topic_df, topic_model, vec, topic_list

def predictive_modeling(df):
    '''
    fits, optimizes, and predicts job class based on topic modeling corpus
    '''
    X,y = df.iloc[:,0:-1], df.iloc[:, -1]
    X_tr, X_te, y_tr, y_te = train_test_split(X,y)

    param_grid = {'n_estimators': [100,300, 400, 500, 600], 'max_depth': [3,7,9, 11]}
    # search = GridSearchCV(RandomForestClassifier(), param_grid, cv=5)
    # search.fit(X_tr, y_tr)
    # bp = search.best_params_
    # print(bp)
    #rfc = RandomForestClassifier(n_estimators = bp['n_estimators'], max_depth = bp['max_depth'])
    rfc = RandomForestClassifier(n_estimators = 500, max_depth = 9)
    rfc.fit(X_tr, y_tr)
    print('acc: ', np.mean(cross_val_score(rfc, X_tr, y_tr, scoring = 'accuracy', cv=5)))
    print('test_acc: ', accuracy_score(y_te, rfc.predict(X_te)))
    print(rfc.predict(X_te))
    return rfc

def predict_resume(topic_model, model, resume):
    '''
    transforms a resume based on the topic modeling model and return prediction probabilities per each job class
    '''
    doc = topic_model.transform(resume)
    return model.predict_proba(doc), model.classes_

def main():
    jobs_df, model, vec, topic_list = process_data()
    model_1 = predictive_modeling(jobs_df)
    
    for i,doc in enumerate(resumes.Resumes):
        doc = tokenize_stem(pd.Series(doc))
        doc = vec.transform(doc)
        #do cosine similarity compared to job 1 to job 100
        #this would spit out the specifc job application + 
        print(resumes.Person[i])
        print('----------------')
        probabilities, classes = predict_resume(model, model_1, doc)
        for i in range(len(probabilities[0])):
            print(classes[i], ': ', probabilities[0][i]*100, '%')
    
#     doc1 = resumes.Resumes[0]
#     doc1 = tokenize_stem(pd.Series(doc1))
#     doc1 = vec.transform(doc1)
    
#     probabilities, classes = predict_resume(model, model_1, doc1)
#     return probabilities, classes
main()
# look at topics and see what makes sense

# recommend roles that are best for you based on supervised learnings

# these are the jobs descriptions that are best for you based on your resume

# these are the best words for your resume based on which job you want to go into


# NEXT STEPS:
# Now we have to fit resumes according to the topic modeling model -
    #we my want to add a new function in here to fit the resumes and test out the product

    #then we have to turn the model into a streamlit app

    #last we want to make the app pretty and have users test it / upload it to the internet for real

    #make presentation

# Also have to create app and return the

#get chart of top toppics from topic modeling
# Out:
# model components:  (5261,)
# doc_topic [ 0.33272073  0.276463   -0.07798587 -0.0465505   0.05011158  0.02262491
#  -0.00869527  0.01852186  0.06832154  0.09337712 -0.03013376  0.04280977
#  -0.09286832  0.00764072 -0.07589047 -0.01436479 -0.05664589 -0.009486
#   0.07018187 -0.09984484]
#
# Topic  0
# sale, manag, work, experi, design, project, custom, market, product, client
#
# Topic  1
# design, ux, user, data, ui, visual, experi, product, interact, prototyp
#
# Topic  2
# project, construct, manag, consult, data, client, subcontractor, report, budget, owner
#
# Topic  3
# market, data, analyt, consult, busi, sale, analyst, campaign, strategi, help
#
# Topic  4
# client, consult, strategi, firm, valu, busi, peopl, team, servic, deliv
#
# Topic  5
# market, campaign, content, email, brand, media, manag, channel, growth, digit
#
# Topic  6
# sale, construct, project, custom, roostifi, help, solar, lend, roof, understand
#
# Topic  7
# sale, clinic, consult, project, trial, diagnost, molecular, healthcar, biolog, research
#
# Topic  8
# product, roostifi, custom, clinic, lend, manag, account, trial, molecular, technic
#
# Topic  9
# diagnost, biolog, molecular, scientif, clinic, consult, healthcar, adivo, product, year
#
# Topic  10
# diagnost, estimates, biolog, molecular, bid, clinic, client, scientif, birdey, world
#
# Topic  11
# assist, estimates, consult, bid, strong, roostifi, product, sale, good, skill
#
# Topic  12
# adivo, custom, consult, construct, healthcar, market, roostifi, model, product, increas
#
# Topic  13
# custom, roof, product, order, awt, superintendent, dropbox, birdey, file, data
#
# Topic  14
# birdey, everi, insur, skills, customers, yahoo, mean, employe, ms, trial
#
# Topic  15
# paypal, assist, roostifi, research, roof, lend, polici, includ, enrol, file
#
# Topic  16
# dropbox, roostifi, lend, project, commiss, mgr, new, floor, trial, multifamili
#
# Topic  17
# ms, strong, rapport, increas, enthusiast, doer, hghw, repeat, 16, database
#
# Topic  18
# slakey, brother, plumb, hvac, dropbox, project, paypal, insid, technic, customers
#
# Topic  19
# dropbox, peopl, survey, product, paypal, work, world, intern, sale, order
# acc:  0.8648275862068966
# test_acc:  0.88
# ['project,manager' 'ux,designer' 'ux,designer' 'sales' 'data,analyst'
#  'product,manager' 'data,analyst' 'product,manager' 'sales'
#  'project,manager' 'sales' 'marketing' 'product,manager' 'sales'
#  'ux,designer' 'ux,designer' 'data,analyst' 'ux,designer' 'sales'
#  'data,analyst' 'sales' 'sales' 'consultant' 'sales' 'data,analyst'
#  'ux,designer' 'consultant' 'account,manager' 'sales' 'account,manager'
#  'data,analyst' 'product,manager' 'sales' 'marketing' 'sales' 'sales'
#  'sales' 'sales' 'marketing' 'sales' 'product,manager' 'ux,designer'
#  'account,manager' 'account,manager' 'sales' 'consultant'
#  'project,manager' 'sales' 'data,analyst' 'sales']
# Ryan Clohessy
# ----------------
# account,manager :  3.244292549555708 %
# consultant :  11.60897546897547 %
# data,analyst :  12.21008658008658 %
# marketing :  45.44415195915196 %
# product,manager :  13.770754245754244 %
# project,manager :  1.7777777777777777 %
# sales :  7.300382775119616 %
# ux,designer :  4.6435786435786435 %
# Russell Escalada
# ----------------
# account,manager :  8.994699269272774 %
# consultant :  22.974535856863444 %
# data,analyst :  6.643910533910533 %
# marketing :  17.194135538790707 %
# product,manager :  19.258102357412703 %
# project,manager :  2.613113132078649 %
# sales :  12.359472287140164 %
# ux,designer :  9.962031024531024 %
# Xiu Li
# ----------------
# account,manager :  13.221365935939437 %
# consultant :  15.037363584691171 %
# data,analyst :  6.08094239094239 %
# marketing :  17.435564110219282 %
# product,manager :  14.913981478291822 %
# project,manager :  4.753351227316745 %
# sales :  22.32455165221953 %
# ux,designer :  6.23287962037962 %
# Shawdon Zadeh
# ----------------
# account,manager :  2.5806893106893107 %
# consultant :  55.217373737373734 %
# data,analyst :  10.431212121212123 %
# marketing :  12.701313131313134 %
# product,manager :  3.3615744400527 %
# project,manager :  8.42173382173382 %
# sales :  4.440143841665582 %
# ux,designer :  2.845959595959596 %
# Courtney Schaf
# ----------------
# account,manager :  15.173920048493553 %
# consultant :  17.1026383099659 %
# data,analyst :  5.112395382395382 %
# marketing :  15.37256988222506 %
# product,manager :  23.990100914411258 %
# project,manager :  2.2450972590627765 %
# sales :  11.106723369391247 %
# ux,designer :  9.896554834054834 %
# Preston Lam
# ----------------
# account,manager :  6.755088879662383 %
# consultant :  29.51751204733963 %
# data,analyst :  16.922005772005775 %
# marketing :  19.66738950704468 %
# product,manager :  10.02881664312699 %
# project,manager :  4.200652814618332 %
# sales :  7.030828708496586 %
# ux,designer :  5.877705627705628 %
# CPU times: user 11.1 s, sys: 373 ms, total: 11.5 s
# Wall time: 13.5 s

# %%
import matplotlib.pyplot as plt

# %%
def create_clusters():
    topic_df, model, vec, topic_list = process_data()
    pca = PCA(n_components=2)
    X_train = topic_df.iloc[:, :-1]
    y_train = topic_df.iloc[:, -1]
    y_vals = y_train.unique()
    pca.fit(X_train)
    return X_train, pca.transform(X_train), y_train, y_vals, topic_list
     
from itertools import cycle

def plot_PCA_2D(data, target, target_names):
    colors = cycle(['r','g','b','c','m','y','orange','w','aqua','yellow'])
    target_ids = range(len(target_names))
    plt.figure(figsize=(10,10))
    for i, c, label in zip(target_ids, colors, target_names):
        plt.scatter(data[target == i, 0], data[target == i, 1],
                   c=c, label=label, edgecolors='gray')
    plt.xlabel('Marketing Related Words')
    plt.ylabel('Data Related Words')
    plt.legend()

# %%
X_train, pca_train, y_train, y_vals, topic_list = create_clusters()

for i, val in enumerate(y_train.unique()):
    y_train = y_train.apply(lambda x: i if x == val else x)


plot_PCA_2D(pca_train, y_train, y_vals)
# Out:
# model components:  (5261,)
# doc_topic [ 0.33272074  0.27647104 -0.07799984 -0.04648952  0.04999026  0.021367
#  -0.00604171  0.02650805  0.07334236  0.08935068 -0.00346631  0.03760901
#  -0.10788866  0.03504401 -0.04666136 -0.02397621  0.01019922  0.00979101
#   0.03610053 -0.04340062]
#
# Topic  0
# sale, manag, work, experi, design, project, custom, market, product, client
#
# Topic  1
# design, ux, user, data, ui, visual, experi, product, interact, prototyp
#
# Topic  2
# project, construct, manag, consult, data, client, subcontractor, report, budget, owner
#
# Topic  3
# market, data, analyt, consult, busi, sale, analyst, campaign, strategi, help
#
# Topic  4
# client, consult, strategi, firm, valu, busi, peopl, team, servic, deliv
#
# Topic  5
# market, campaign, content, email, brand, media, manag, channel, growth, social
#
# Topic  6
# sale, construct, project, custom, roostifi, help, solar, roof, lend, understand
#
# Topic  7
# sale, clinic, consult, project, trial, diagnost, molecular, biolog, healthcar, develop
#
# Topic  8
# product, roostifi, custom, clinic, lend, manag, trial, account, technic, molecular
#
# Topic  9
# diagnost, biolog, molecular, consult, product, clinic, adivo, healthcar, scientif, year
#
# Topic  10
# diagnost, biolog, molecular, client, clinic, scientif, estimates, birdey, bid, world
#
# Topic  11
# assist, estimates, bid, consult, strong, good, takeoffs, _locat, _duties, _qualif
#
# Topic  12
# adivo, custom, market, consult, construct, healthcar, product, model, paypal, employ
#
# Topic  13
# custom, order, roof, dropbox, birdey, awt, superintendent, file, reconstruct, data
#
# Topic  14
# birdey, ms, customers, skills, insur, everi, increas, mean, attitud, yahoo
#
# Topic  15
# paypal, assist, account, order, licens, roof, employe, world, person, home
#
# Topic  16
# roostifi, lend, ms, new, research, dropbox, increas, satisfaction, rapport, strong
#
# Topic  17
# deloitt, strong, test, ms, epic, consult, experi, construct, autodesk, solut
#
# Topic  18
# slakey, deloitt, account, roostifi, technic, paypal, brother, birdey, architectur, test
#
# Topic  19
# slakey, brother, client, hvac, plumb, skill, demonstr, biolog, commun, appli

# %%
def get_topic_words():
    jobs_df, model, vec, topic_list = process_data()
    
    topic_dict = {}
    for i in range(0, len(topic_list)):
        topic_dict[i] = topic_list[i]
    return topic_dict

# %%
pca = PCA(n_components = 2)
pca.fit(X_train)
X_transf = pca.transform(X_train)
print("shape of original X_train:", X_train.shape)
print("shape of X_train using 2 principal components:", X_transf.shape, "\n")
print(X_transf)
# Out:
# shape of original X_train: (197, 20)
# shape of X_train using 2 principal components: (197, 2)
#
# [[ 2.72080594e-01 -7.74983546e-02]
#  [ 2.64472140e-01 -1.02224706e-01]
#  [ 2.13911054e-01 -1.33536419e-01]
#  [ 4.26754902e-01 -1.59611947e-01]
#  [ 3.07213161e-01 -2.11727656e-01]
#  [ 4.47869505e-01 -1.78261173e-01]
#  [ 3.78954019e-01 -1.61259612e-01]
#  [ 3.03386111e-01 -1.15216943e-01]
#  [ 3.32142564e-01 -1.36201688e-01]
#  [ 1.91056721e-01 -7.72059781e-02]
#  [ 1.11274921e-01 -4.25640372e-02]
#  [ 3.32677557e-01 -9.88088056e-02]
#  [ 3.48766151e-01 -1.59928908e-01]
#  [ 4.21219685e-01 -1.58361923e-01]
#  [ 2.70182992e-01 -8.22141177e-02]
#  [ 4.92900688e-01 -1.70562736e-01]
#  [ 4.73164226e-01 -1.77779982e-01]
#  [ 4.42833588e-01 -1.72171995e-01]
#  [ 4.34797117e-01 -1.29235824e-01]
#  [ 3.03486553e-01 -1.38934358e-01]
#  [ 1.70173493e-01 -1.26861812e-01]
#  [ 3.34565788e-01 -2.06859976e-01]
#  [ 3.65326182e-01 -1.40052869e-01]
#  [ 2.88703332e-01 -1.84192717e-01]
#  [ 3.54347427e-01 -5.71906717e-02]
#  [ 4.54590565e-01 -2.00418635e-01]
#  [ 8.48142139e-02  1.13560035e-01]
#  [ 1.26458206e-01  1.23849126e-01]
#  [ 4.40252294e-02  1.50019430e-01]
#  [ 1.43035843e-02  9.90045751e-02]
#  [ 1.43453972e-01  1.26475114e-01]
#  [ 1.29550222e-01  2.19237180e-02]
#  [ 1.80925925e-01  1.08278704e-01]
#  [ 1.35860208e-01  6.45352145e-02]
#  [ 3.28288012e-02  1.63857059e-01]
#  [ 1.40690507e-01  5.46059236e-02]
#  [ 5.31987037e-02  7.25473198e-02]
#  [ 8.64097092e-02  1.43611888e-01]
#  [ 1.29001552e-01  2.18249163e-02]
#  [ 1.31572544e-01  1.45205069e-01]
#  [ 1.10266299e-01  5.87850808e-02]
#  [ 9.59819487e-02  1.26916802e-01]
#  [ 2.01088617e-01  1.09755445e-01]
#  [ 1.82651677e-01  1.36163217e-01]
#  [-7.89750395e-03  8.06395196e-02]
#  [ 1.96802677e-02  2.24437153e-01]
#  [ 1.35627386e-01  1.18641281e-01]
#  [ 1.41985093e-01  8.13990300e-02]
#  [-1.37879684e-01 -9.43437261e-02]
#  [-1.66525668e-01  2.19563943e-02]
#  [-1.71108936e-01 -8.44103902e-02]
#  [-1.85136214e-01 -8.84284018e-02]
#  [-4.93023664e-02 -8.64001833e-02]
#  [-1.51699033e-01 -1.39155313e-01]
#  [-1.56615250e-01 -1.61089451e-01]
#  [-1.03478976e-02 -4.43314159e-02]
#  [-1.93526083e-01 -1.45492020e-01]
#  [-1.99783582e-01 -1.55933655e-01]
#  [-1.64156499e-01 -1.84883344e-01]
#  [-1.91253218e-01 -1.56230706e-01]
#  [-1.51735080e-01 -1.08224602e-01]
#  [-1.59268739e-01 -1.51418976e-01]
#  [-2.20111870e-01 -1.23506083e-01]
#  [-2.65772812e-01 -2.42660499e-01]
#  [-2.40900569e-01 -1.27315799e-01]
#  [-2.66372968e-01 -2.88294570e-01]
#  [-1.43452940e-01 -3.83690535e-02]
#  [-1.84493763e-01 -1.89401873e-01]
#  [-4.53581987e-02 -6.37748396e-02]]

# %%
pca.explained_variance_ratio_
# Out:
# array([0.14791819, 0.09881927])

# %%
pca_df = pd.DataFrame(pca.components_, index = ['PC1','PC2'])

# %%
topic_dict = get_topic_words()
pca_df.columns = [topic_dict[i] for i in range(len(pca_df.columns))]
pca_df
# Out:
# model components:  (5261,)
# doc_topic [ 0.33272074  0.27646693 -0.07795172 -0.04657683  0.05066971  0.0220977
#  -0.00785686  0.02394755  0.07107293  0.09568044 -0.02117823  0.05782547
#  -0.11127465 -0.0255851  -0.05609016 -0.01768868  0.02730145 -0.06868201
#   0.08429528 -0.01996749]
#
# Topic  0
# sale, manag, work, experi, design, project, custom, market, product, client
#
# Topic  1
# design, ux, user, data, ui, visual, experi, product, interact, prototyp
#
# Topic  2
# project, construct, manag, consult, data, client, subcontractor, report, budget, owner
#
# Topic  3
# market, data, analyt, consult, busi, sale, analyst, campaign, strategi, help
#
# Topic  4
# client, consult, strategi, firm, valu, busi, peopl, team, servic, deliv
#
# Topic  5
# market, campaign, content, email, brand, media, manag, channel, growth, digit
#
# Topic  6
# sale, construct, project, custom, roostifi, solar, help, roof, lend, understand
#
# Topic  7
# sale, clinic, consult, project, trial, diagnost, molecular, biolog, research, healthcar
#
# Topic  8
# product, custom, roostifi, clinic, lend, manag, account, trial, molecular, biolog
#
# Topic  9
# diagnost, biolog, molecular, consult, product, scientif, healthcar, adivo, clinic, year
#
# Topic  10
# diagnost, biolog, molecular, birdey, estimates, bid, scientif, client, clinic, solar
#
# Topic  11
# assist, estimates, bid, consult, strong, good, skill, caroneandcompany, _locat, negotiable
#
# Topic  12
# adivo, custom, consult, healthcar, market, construct, product, model, employ, strategi
#
# Topic  13
# dropbox, custom, roof, order, product, client, file, superintendent, awt, reconstruct
#
# Topic  14
# birdey, everi, skills, ms, customers, trial, dropbox, insur, yahoo, mean
#
# Topic  15
# paypal, assist, roof, research, employe, file, enrol, awt, superintendent, dropbox
#
# Topic  16
# roostifi, lend, slakey, technic, solar, project, brother, new, insur, prospect
#
# Topic  17
# dropbox, birdey, slakey, research, brother, survey, medicar, solar, servic, care
#
# Topic  18
# slakey, paypal, brother, deloitt, plumb, hvac, test, servic, birdey, technic
#
# Topic  19
# dropbox, paypal, peopl, financi, epic, increas, ux, slakey, custom, skills
#                     sale, manag, work, experi, design, project, custom, market, product, client  \
# UX Related Words                                            -0.048300
# Data Related Words                                           0.006644
#
#                     design, ux, user, data, ui, visual, experi, product, interact, prototyp  \
# UX Related Words                                             0.998817
# Data Related Words                                           0.000696
#
#                     project, construct, manag, consult, data, client, subcontractor, report, budget, owner  \
# UX Related Words                                            -0.000363
# Data Related Words                                           0.999975
#
#                     market, data, analyt, consult, busi, sale, analyst, campaign, strategi, help  \
# UX Related Words                                            -0.000740
# Data Related Words                                           0.001434
#
#                     client, consult, strategi, firm, valu, busi, peopl, team, servic, deliv  \
# UX Related Words                                            -0.001741
# Data Related Words                                           0.000708
#
#                     market, campaign, content, email, brand, media, manag, channel, growth, digit  \
# UX Related Words                                            -0.003371
# Data Related Words                                           0.001193
#
#                     sale, construct, project, custom, roostifi, solar, help, roof, lend, understand  \
# UX Related Words                                             0.000761
# Data Related Words                                          -0.000243
#
#                     sale, clinic, consult, project, trial, diagnost, molecular, biolog, research, healthcar  \
# UX Related Words                                            -0.000474
# Data Related Words                                           0.000146
#
#                     product, custom, roostifi, clinic, lend, manag, account, trial, molecular, biolog  \
# UX Related Words                                            -0.002701
# Data Related Words                                           0.000795
#
#                     diagnost, biolog, molecular, consult, product, scientif, healthcar, adivo, clinic, year  \
# UX Related Words                                             0.002264
# Data Related Words                                          -0.000656
#
#                     diagnost, biolog, molecular, birdey, estimates, bid, scientif, client, clinic, solar  \
# UX Related Words                                             0.001080
# Data Related Words                                          -0.000306
#
#                     assist, estimates, bid, consult, strong, good, skill, caroneandcompany, _locat, negotiable  \
# UX Related Words                                             0.000553
# Data Related Words                                          -0.000155
#
#                     adivo, custom, consult, healthcar, market, construct, product, model, employ, strategi  \
# UX Related Words                                            -0.000929
# Data Related Words                                           0.000259
#
#                     dropbox, custom, roof, order, product, client, file, superintendent, awt, reconstruct  \
# UX Related Words                                            -0.000010
# Data Related Words                                           0.000003
#
#                     birdey, everi, skills, ms, customers, trial, dropbox, insur, yahoo, mean  \
# UX Related Words                                            -0.000030
# Data Related Words                                           0.000008
#
#                     paypal, assist, roof, research, employe, file, enrol, awt, superintendent, dropbox  \
# UX Related Words                                             0.001019
# Data Related Words                                          -0.000276
#
#                     roostifi, lend, slakey, technic, solar, project, brother, new, insur, prospect  \
# UX Related Words                                            -0.000158
# Data Related Words                                           0.000043
#
#                     dropbox, birdey, slakey, research, brother, survey, medicar, solar, servic, care  \
# UX Related Words                                            -0.000561
# Data Related Words                                           0.000151
#
#                     slakey, paypal, brother, deloitt, plumb, hvac, test, servic, birdey, technic  \
# UX Related Words                                            -0.000619
# Data Related Words                                           0.000166
#
#                     dropbox, paypal, peopl, financi, epic, increas, ux, slakey, custom, skills
# UX Related Words                                             0.000532
# Data Related Words                                          -0.000141
