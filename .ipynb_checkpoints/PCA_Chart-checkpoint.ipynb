# %%
import pandas as pd
import numpy as np
import process_data as pda
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from itertools import cycle

def create_clusters():
    topic_df, model, vec, topic_list = pda.process_data()
    pca = PCA(n_components=2)
    X_train = topic_df.iloc[:, :-1]
    y_train = topic_df.iloc[:, -1]
    y_vals = y_train.unique()
    model = pca.fit(X_train)
    
    return X_train, model.transform(X_train), y_train, y_vals, topic_list, model
     


def plot_PCA_2D(data, target, target_names, user_data):
    colors = cycle(['black','g','b','c','m','y','orange','w','aqua','yellow'])
    target_ids = range(len(target_names))
    plt.figure(figsize=(10,10))
    for i, c, label in zip(target_ids, colors, target_names):
        plt.scatter(data[target == i, 0], data[target == i, 1],
                   c=c, label=label, edgecolors='gray')
    plt.scatter(user_data[0][0], user_data[0][1], s= 150, color = 'red')
    plt.title('Clustering Job Archetypes')
    plt.xlabel('Marketing Design Words')
    plt.ylabel('Project Management Words')
    plt.legend()
    
def transform_user_resume(pca_model, resume):
    ''' 
    take in resume and fit it according to both count vectorizer and PCA model
    '''
    jobs_df, topic_model, vec, topic_list = pda.process_data()
    doc = pda.tokenize_stem(resume)
    doc = vec.transform(doc)
    doc = topic_model.transform(doc)
    doc = pd.DataFrame(doc)
#     X_train = doc.iloc[:, :-1]
#     y_train = doc.iloc[:, -1]
#     y_vals = y_train.unique()
    doc = pca_model.transform(doc)
    return doc
    
    
    
X_train, pca_train, y_train, y_vals, topic_list, pca_model = create_clusters()

for i, val in enumerate(y_train.unique()):
    y_train = y_train.apply(lambda x: i if x == val else x)



#now how do we incorporate user inputs
    #get user input
    #transform according to PCA
    #plt on same chart as PCA

# %%
resumes = pd.read_csv('resumes.csv')
example = pd.Series(resumes.Resumes[0])
doc = transform_user_resume(pca_model, example)

plot_PCA_2D(pca_train, y_train, y_vals, doc)

# %%
def get_topic_words():
    jobs_df, model, vec, topic_list = pda.process_data()
    
    topic_dict = {}
    for i in range(0, len(topic_list)):
        topic_dict[i] = topic_list[i]
    return topic_dict


pca = PCA(n_components = 2)
pca.fit(X_train)
X_transf = pca.transform(X_train)
print("shape of original X_train:", X_train.shape)
print("shape of X_train using 2 principal components:", X_transf.shape, "\n")
print(X_transf)

pca_df = pd.DataFrame(pca.components_, index = ['PC1','PC2'])

topic_dict = get_topic_words()
pca_df.columns = [topic_dict[i] for i in range(len(pca_df.columns))]
pca_df
# Out:
# shape of original X_train: (197, 20)
# shape of X_train using 2 principal components: (197, 2)
#
# [[ 2.72128360e-01 -7.74600115e-02]
#  [ 2.64485240e-01 -1.02112782e-01]
#  [ 2.13969835e-01 -1.33503787e-01]
#  [ 4.26769773e-01 -1.59643518e-01]
#  [ 3.07439953e-01 -2.11873168e-01]
#  [ 4.47865762e-01 -1.78314602e-01]
#  [ 3.78929543e-01 -1.61160384e-01]
#  [ 3.03309700e-01 -1.15281102e-01]
#  [ 3.32276948e-01 -1.36298419e-01]
#  [-1.59137795e-01 -1.51608212e-01]
#  [-2.19978962e-01 -1.23511168e-01]
#  [-2.65811956e-01 -2.42650445e-01]
#  [-2.40048867e-01 -1.26760702e-01]
#  [-2.66408800e-01 -2.88268186e-01]
#  [-1.43423153e-01 -3.83566208e-02]
#  [-1.84385374e-01 -1.89518187e-01]
#  [-4.54681897e-02 -6.36868938e-02]]
#      sale, manag, work, experi, design, project, custom, market, product, client  \
# PC1                                          -0.048293
# PC2                                           0.006663
#
#      design, ux, user, data, ui, visual, experi, product, interact, prototyp  \
# PC1                                           0.998816
# PC2                                           0.000697
#
#      project, construct, manag, consult, data, client, subcontractor, report, budget, owner  \
# PC1                                          -0.000362
# PC2                                           0.999975
#
#      market, data, analyt, consult, busi, sale, analyst, campaign, strategi, help  \
# PC1                                           -0.00074
# PC2                                            0.00144
#
#      client, consult, strategi, firm, valu, busi, peopl, team, servic, deliv  \
# PC1                                          -0.001757
# PC2                                           0.000717
#
#      market, campaign, content, email, brand, media, manag, channel, growth, social  \
# PC1                                          -0.003377
# PC2                                           0.001199
#
#      sale, construct, project, custom, roostifi, help, solar, lend, roof, understand  \
# PC1                                           0.000779
# PC2                                          -0.000249
#
#      sale, clinic, consult, trial, project, diagnost, molecular, research, healthcar, biolog  \
# PC1                                          -0.000538
# PC2                                           0.000166
#
#      product, roostifi, custom, lend, clinic, manag, account, trial, molecular, biolog  \
# PC1                                          -0.002512
# PC2                                           0.000742
#
#      diagnost, biolog, molecular, clinic, scientif, consult, adivo, healthcar, product, prefer  \
# PC1                                           0.002363
# PC2                                          -0.000687
#
#      diagnost, biolog, molecular, birdey, estimates, client, scientif, bid, clinic, world  \
# PC1                                           0.001173
# PC2                                          -0.000334
#
#      assist, estimates, bid, sale, consult, strong, good, skill, work, p6  \
# PC1                                           0.000825
# PC2                                          -0.000232
#
#      adivo, custom, healthcar, consult, construct, market, paypal, model, product, statu  \
# PC1                                          -0.000924
# PC2                                           0.000258
#
#      dropbox, birdey, custom, roof, order, file, awt, superintendent, reconstruct, capabl  \
# PC1                                            0.00029
# PC2                                           -0.00008
#
#      birdey, insur, everi, ms, customers, trial, skills, increas, clinic, mean  \
# PC1                                           0.000141
# PC2                                          -0.000039
#
#      paypal, assist, roof, ux, insur, employe, includ, account, enrol, superintendent  \
# PC1                                           0.000848
# PC2                                          -0.000231
#
#      roostifi, slakey, lend, solar, brother, technic, hvac, plumb, project, best  \
# PC1                                          -0.000343
# PC2                                           0.000093
#
#      ms, 00, client, new, skill, strong, enthusiast, doer, hghw, increas  \
# PC1                                          -0.000973
# PC2                                           0.000263
#
#      slakey, deloitt, experi, brother, test, solut, technic, construct, plumb, skill  \
# PC1                                           0.001147
# PC2                                          -0.000308
#
#      slakey, brother, plumb, project, dropbox, peopl, hire, hvac, team, strong
# PC1                                          -0.000536
# PC2                                           0.000143
